# %%
import numpy as np
import pandas as pd

# %%
data_list=list()
data_trager=dict()
for i in range(1,8):
    path=r'/Users/hurrywish/Desktop/Jupyter/SalesRecords/SalesRecords{}.csv'
    path=path.format(i)
    
    data=pd.read_csv(path,chunksize=10000) #块读取
    data_list=list(data)
    
    for j in range(len(data_list)):
        data_trager['%d-%d'%(i,j)]=data_list[j]

# %%
data_trager.keys()
len(data_trager)
# Out:
# 515

# %%
data_trager_pd=pd.concat(data_trager,axis=0,ignore_index=True)
data_trager_pd
# Out:
#                                Region           Country  Item Type  \
# 0                  Sub-Saharan Africa           Namibia  Household
# 1                              Europe           Iceland  Baby Food
# 2                              Europe            Russia       Meat
# 3                              Europe          Moldova        Meat
# 4                              Europe             Malta     Cereal
# ...                               ...               ...        ...
# 5149995                          Asia        Bangladesh  Beverages
# 5149996                        Europe           Denmark  Baby Food
# 5149997  Middle East and North Africa            Jordan     Cereal
# 5149998            Sub-Saharan Africa          Djibouti     Fruits
# 5149999         Australia and Oceania  Papua New Guinea  Baby Food
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0             Offline              M   8/31/2015  897751939  10/12/2015
# ...

# %%
data_list=list()
for i in range(1,8):
    path=r'/Users/hurrywish/Desktop/Jupyter/SalesRecords/SalesRecords{}.csv'
    path=path.format(i)
    
    data=pd.read_csv(path,chunksize=10000) #块读取
    data_list_small=list(data)
    
    for j in range(len(data_list_small)):
        data_list.append(data_list_small[j])

# %%
data_list
# Out:
# [                                 Region   Country  Item Type Sales Channel  \
#  0                    Sub-Saharan Africa   Namibia  Household       Offline
#  1                                Europe   Iceland  Baby Food        Online
#  2                                Europe    Russia       Meat        Online
#  3                                Europe  Moldova        Meat        Online
#  4                                Europe     Malta     Cereal        Online
#  ...                                 ...       ...        ...           ...
#  9995       Middle East and North Africa      Oman  Baby Food        Online
#  9996                             Europe   Ireland  Baby Food        Online
#  9997       Middle East and North Africa   Lebanon  Beverages        Online
#  9998                             Europe   Austria  Cosmetics        Online
#  9999  Central America and the Caribbean  Honduras     Cereal        Online
#
# ...

# %%
def combine(data):
    data_pd=pd.concat(data,axis=0,ignore_index=True)
    return data_pd

# %%
combine(data_list)
# Out:
#                                Region           Country  Item Type  \
# 0                  Sub-Saharan Africa           Namibia  Household
# 1                              Europe           Iceland  Baby Food
# 2                              Europe            Russia       Meat
# 3                              Europe          Moldova        Meat
# 4                              Europe             Malta     Cereal
# ...                               ...               ...        ...
# 5149995                          Asia        Bangladesh  Beverages
# 5149996                        Europe           Denmark  Baby Food
# 5149997  Middle East and North Africa            Jordan     Cereal
# 5149998            Sub-Saharan Africa          Djibouti     Fruits
# 5149999         Australia and Oceania  Papua New Guinea  Baby Food
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0             Offline              M   8/31/2015  897751939  10/12/2015
# ...
