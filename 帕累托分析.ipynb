# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.Series(np.random.randn(10)*1200+3000,index=list('abcdefghij'))

# %%
data
# Out:
# a    3028.301119
# b    2996.336474
# c    2660.745595
# d    2796.092584
# e    4052.585984
# f    1512.272955
# g    4750.924187
# h    5650.730321
# i    1292.380093
# j    2211.091552
# dtype: float64

# %%
data.sort_values(ascending=False,inplace=True)

# %%
data
# Out:
# h    5650.730321
# g    4750.924187
# e    4052.585984
# a    3028.301119
# b    2996.336474
# d    2796.092584
# c    2660.745595
# j    2211.091552
# f    1512.272955
# i    1292.380093
# dtype: float64

# %%
plt.figure(figsize=(10,8))
data.plot.bar(alpha=0.5,width=0.8)
p.plot(secondary_y=True,ls='-',lw=1,color='red',alpha=0.5,marker='*')
plt.axvline(key_num,lw=1,ls='--')

# %%
p=np.cumsum(data)/np.sum(data)
key=p[p>0.8].index[0]
key_num=data.index.tolist().index(key)
key,key_num
# Out:
# ('c', 6)

# %%
# Out:
# Index(['c', 'j', 'f', 'i'], dtype='object')

# %%
fig=plt.subplots(figsize=(10,8))
ax1=plt.subplot(121)
ax1.plot(range(10),np.random.randn(10))
ax2=plt.subplot(121)
ax2.twinx()
ax2.plot(range(10),np.random.randn(10))
# Out:
# /Users/hurrywish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.
