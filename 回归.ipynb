# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model  import LinearRegression
# %matplotlib inline
# Out:
# /Users/hurrywish/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
rng=np.random.RandomState(1)
xtrain=10*rng.rand(30)
ytrain=11*xtrain+rng.rand(30)*30+6
plt.figure(figsize=(12,10))
plt.scatter(xtrain,ytrain,s=2)
plt.plot(xtest,ytest,c='red',lw=0.5,ls='--')
plt.scatter(xtrain,ytest2,s=2,marker='*')
plt.plot([xtrain,xtrain],[ytrain,ytest2],c='k',lw=0.5)

# %%
model=LinearRegression()
model.fit(xtrain.reshape(-1,1),ytrain)
model.coef_,model.intercept_
# Out:
# (array([11.13452413]), 19.42978498293082)

# %%
xtest=np.arange(0,10,0.1)
ytest=model.predict(xtest.reshape(-1,1))
ytest2=model.predict(xtrain.reshape(-1,1))

# %%
rng=np.random.RandomState(30)
xtrain=10+rng.rand(150,4)
ytrain=np.dot(xtrain,[1,2,3,4])
data=pd.DataFrame(xtrain,columns=['b1','b2','b3','b4'])
data['y']=ytrain+10*rng.rand(150)
data.head(10)
# Out:
#           b1         b2         b3         b4           y
# 0  10.644144  10.380748  10.663048  10.163651  112.512281
# 1  10.962608  10.346662  10.991751  10.235058  106.366029
# 2  10.585694  10.406690  10.136234  10.544136  105.660460
# 3  10.518176  10.766855  10.933850  10.089703  108.349650
# 4  10.195771  10.994194  10.235180  10.238986  108.555605
# 5  10.629100  10.734953  10.688344  10.031131  105.818799
# 6  10.902514  10.286435  10.555613  10.376420  113.490282
# 7  10.026624  10.494149  10.834715  10.366987  113.327427
# 8  10.515382  10.472379  10.386152  10.744137  112.031478
# 9  10.335242  10.595438  10.316133  10.346250  106.232760

# %%
pd.plotting.scatter_matrix(data[['b1','b2','b3','b4']],figsize=(12,10),diagonal='kde',alpha=0.5,range_padding=0.1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc534439790>,
# ...
#       dtype=object)

# %%
model=LinearRegression()
model.fit(data[['b1','b2','b3','b4']],data['y'])
model.coef_,model.intercept_
# Out:
# (array([0.961165  , 1.18982583, 2.78192105, 3.57287735]), 21.20283455816174)

# %%
from sklearn import metrics

# %%
rng=np.random.RandomState(2)

# %%
xtrain=10*rng.rand(30)
ytrain=8+4*xtrain+rng.rand(30)*3

# %%
model=LinearRegression()
model.fit(xtrain.reshape(-1,1),ytrain)
ytest=model.predict(xtrain.reshape(-1,1))

# %%
mse=metrics.mean_squared_error(ytrain,ytest)
rmse=np.sqrt(mse)
mse,rmse
# Out:
# (0.6899673446514236, 0.8306427298492557)

# %%
ssr=((ytest-ytrain.mean())**2).sum()

# %%
sst=((ytrain-ytrain.mean())**2).sum()

# %%
r2=ssr/sst

# %%
r2
# Out:
# 0.9920030805707815

# %%
r2_1=model.score(xtrain.reshape(-1,1),ytrain)

# %%
r2_1
# Out:
# 0.9920030805707826
